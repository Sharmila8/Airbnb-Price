# %% [markdown]
# Airbnb Scraper
# --------------
#
# This script extracts all listings from the Airbnb search pages for NYC, SF, and LA, then parses them into a table of features that will be used to model pricing of Airbnb sublets.
#
# BeautifulSoup is used to handle both scraping and crawling. A spoofed header (hdr) is necessary to gain access to the website in this manner.

# %%
import time                                                                                                                                             
from bs4 import BeautifulSoup
import re
import urllib2

hdr = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11'}

# %% [markdown]
# Compile URLs of listings
# ------------------------
#
# This script will loop through the Airbnb search pages. For each search page, the URLs of the displayed listings are extracted and placed into a list for later retrieval.

# %%
list_urls = []
prepostfixlist = [['https://www.airbnb.com/s/New-York--NY?ss_id=q1z6m0pk&page=','&s_tag=Swm8IKOK'],['https://www.airbnb.com/s/San-Francisco--CA?ss_id=ng0pw1xp&page=','&s_tag=He2d5ecU'],['https://www.airbnb.com/s/Los-Angeles?ss_id=gxqwgcby&page=','&s_tag=nhhRjOBR']]
for prepostfix in prepostfixlist:
    for i in range(1,18):
        current_url = prepostfix[0] + str(i) + prepostfix[1]
        #start_urls.append(current_url)
        req = urllib2.Request(current_url, headers=hdr)
        r = urllib2.urlopen(req).read()
        soup = BeautifulSoup(r, "lxml")
        for link in soup('a'):
            try:
                link['class']
            except KeyError:
                continue
            if link['class'] == ['media-photo','media-cover']:
                list_urls.append(link['href'])

# %% [markdown]
# Data Extraction
# ------------------
#
# Each listing is opened up, and 44 variables are extracted into a dictionary representing the listing.

# %%
items = []
prefix = 'https://www.airbnb.com'
counter = 0
for list_url in list_urls:
    counter += 1
    print "Number of pages scraped = " + str(counter)
    # Make a 10-second delay to avoid exceeding rate limit.
    time.sleep(10)
    req = urllib2.Request(prefix + list_url, headers=hdr)
    r = urllib2.urlopen(req).read()
    soup = BeautifulSoup(r, "lxml")
    item = {}
    for metadat in soup('meta'):
        try:
            metadat['content']
        except KeyError:
            continue
        if 'nightly_price' in metadat['content']:
            line = re.sub('false','False',metadat['content'])
            line = re.sub('true','True',line)
            line = re.sub('null','None',line)
            # Potential security flaw here! Might want to find a way to avoid eval.
            line = eval(line)
            nightly_price = int(line['nightly_price'].strip('$'))
            item['price'] = nightly_price
            item['isMonthly'] = line['isMonthly']
            item['minNights'] = line['minNights']
            for x in ['hosting_id','bed_type','cancel_policy','checkin_rating','cleanliness_rating','communication_rating','guest_satisfaction_overall','is_superhost','location_rating','person_capacity','picture_count','room_type','saved_to_wishlist_count','value_rating','visible_review_count']:
                item[x] = line['airEventData'][x]
            if 1 in line['airEventData']['amenities']:
                item['hasKitchen'] = True
            else:
                item['hasKitchen'] = False
            if 2 in line['airEventData']['amenities'] or 11 in line['airEventData']['amenities']:
                item['hasInternet'] = True
            else:
                item['hasInternet'] = False
            if 3 in line['airEventData']['amenities']:
                item['hasTV'] = True
            else:
                item['hasTV'] = False
            if 4 in line['airEventData']['amenities']:
                item['hasEssentials'] = True
            else:
                item['hasEssentials'] = False
            if 5 in line['airEventData']['amenities']:
                item['hasShampoo'] = True
            else:
                item['hasShampoo'] = False
            if 6 in line['airEventData']['amenities']:
                item['hasHeating'] = True
            else:
                item['hasHeating'] = False
            if 7 in line['airEventData']['amenities']:
                item['hasAC'] = True
            else:
                item['hasAC'] = False
            if 8 in line['airEventData']['amenities']:
                item['hasWasher'] = True
            else:
                item['hasWasher'] = False
            if 9 in line['airEventData']['amenities']:
                item['hasDryer'] = True
            else:
                item['hasDryer'] = False
            if 10 in line['airEventData']['amenities']:
                item['hasFreeParking'] = True
            else:
                item['hasFreeParking'] = False
            if 12 in line['airEventData']['amenities']:
                item['hasCable'] = True
            else:
                item['hasCable'] = False
            if 13 in line['airEventData']['amenities']:
                item['hasBreakfast'] = True
            else:
                item['hasBreakfast'] = False
            if 14 in line['airEventData']['amenities']:
                item['allowsPets'] = True
            else:
                item['allowsPets'] = False
            if 15 in line['airEventData']['amenities']:
                item['KidFriendly'] = True
            else:
                item['KidFriendly'] = False
            if 16 in line['airEventData']['amenities']:
                item['SuitableforEvents'] = True
            else:
                item['SuitableforEvents'] = False
            if 17 in line['airEventData']['amenities']:
                item['SmokingAllowed'] = True
            else:
                item['SmokingAllowed'] = False
            if 18 in line['airEventData']['amenities']:
                item['WheelchairAccess'] = True
            else:
                item['WheelchairAccess'] = False
            if 19 in line['airEventData']['amenities']:
                item['hasElevator'] = True
            else:
                item['hasElevator'] = False
            if 20 in line['airEventData']['amenities']:
                item['hasFireplace'] = True
            else:
                item['hasFireplace'] = False
            if 21 in line['airEventData']['amenities']:
                item['hasBuzzer'] = True
            else:
                item['hasBuzzer'] = False
            if 22 in line['airEventData']['amenities']:
                item['hasDoorman'] = True
            else:
                item['hasDoorman'] = False
            if 23 in line['airEventData']['amenities']:
                item['hasPool'] = True
            else:
                item['hasPool'] = False
            if 24 in line['airEventData']['amenities']:
                item['hasHotTub'] = True
            else:
                item['hasHotTub'] = False
            if 25 in line['airEventData']['amenities']:
                item['hasGym'] = True
            else:
                item['hasGym'] = False
            if 26 in line['airEventData']['amenities']:
                item['has24HrCheckin'] = True
            else:
                item['has24HrCheckin'] = False
            if 30 in line['airEventData']['amenities']:
                item['LaptopWorkspace'] = True
            else:                                                           
                item['LaptopWorkspace'] = False
            break
    for metadat in soup('meta'):
        try:
            metadat['property']
        except KeyError:
            continue
        if 'airbedandbreakfast:locality' in metadat['property']:
            item['locality'] = metadat['content']
        if 'airbedandbreakfast:city' in metadat['property']:
            item['city'] = metadat['content']
        if 'airbedandbreakfast:region' in metadat['property']:
            item['region'] = metadat['content']
        if 'airbedandbreakfast:latitude' in metadat['property']:
            item['latitude'] = metadat['content']
        if 'airbedandbreakfast:longitude' in metadat['property']:
            item['longitude'] = metadat['content']
        break
    items.append(item)
# Out:
# Number of pages scraped = 1
# Number of pages scraped = 2
# Number of pages scraped = 3
# Number of pages scraped = 4
# Number of pages scraped = 5
# Number of pages scraped = 6
# Number of pages scraped = 7
# Number of pages scraped = 8
# Number of pages scraped = 9
# Number of pages scraped = 10
# Number of pages scraped = 11
# Number of pages scraped = 12
# Number of pages scraped = 13
# Number of pages scraped = 14
# Number of pages scraped = 15
# Number of pages scraped = 16
# Number of pages scraped = 17
# Number of pages scraped = 18
# Number of pages scraped = 19
# Number of pages scraped = 20
# Number of pages scraped = 21
# Number of pages scraped = 22
# Number of pages scraped = 23
# Number of pages scraped = 24
# Number of pages scraped = 25
# Number of pages scraped = 26
# Number of pages scraped = 27
# Number of pages scraped = 28
# Number of pages scraped = 29
# Number of pages scraped = 30
# Number of pages scraped = 31
# Number of pages scraped = 32
# Number of pages scraped = 33
# Number of pages scraped = 34
# Number of pages scraped = 35
# Number of pages scraped = 36
# Number of pages scraped = 37
# Number of pages scraped = 38
# Number of pages scraped = 39
# Number of pages scraped = 40
# Number of pages scraped = 41
# Number of pages scraped = 42
# Number of pages scraped = 43
# Number of pages scraped = 44
# Number of pages scraped = 45
# Number of pages scraped = 46
# Number of pages scraped = 47
# Number of pages scraped = 48
# Number of pages scraped = 49
# Number of pages scraped = 50
# Number of pages scraped = 51
# Number of pages scraped = 52
# Number of pages scraped = 53
# Number of pages scraped = 54
# Number of pages scraped = 55
# Number of pages scraped = 56
# Number of pages scraped = 57
# Number of pages scraped = 58
# Number of pages scraped = 59
# Number of pages scraped = 60
# Number of pages scraped = 61
# Number of pages scraped = 62
# Number of pages scraped = 63
# Number of pages scraped = 64
# Number of pages scraped = 65
# Number of pages scraped = 66
# Number of pages scraped = 67
# Number of pages scraped = 68
# Number of pages scraped = 69
# Number of pages scraped = 70
# Number of pages scraped = 71
# Number of pages scraped = 72
# Number of pages scraped = 73
# Number of pages scraped = 74
# Number of pages scraped = 75
# Number of pages scraped = 76
# Number of pages scraped = 77
# Number of pages scraped = 78
# Number of pages scraped = 79
# Number of pages scraped = 80
# Number of pages scraped = 81
# Number of pages scraped = 82
# Number of pages scraped = 83
# Number of pages scraped = 84
# Number of pages scraped = 85
# Number of pages scraped = 86
# Number of pages scraped = 87
# Number of pages scraped = 88
# Number of pages scraped = 89
# Number of pages scraped = 90
# Number of pages scraped = 91
# Number of pages scraped = 92
# Number of pages scraped = 93
# Number of pages scraped = 94
# Number of pages scraped = 95
# Number of pages scraped = 96
# Number of pages scraped = 97
# Number of pages scraped = 98
# Number of pages scraped = 99
# Number of pages scraped = 100
# Number of pages scraped = 101
# Number of pages scraped = 102
# Number of pages scraped = 103
# Number of pages scraped = 104
# Number of pages scraped = 105
# Number of pages scraped = 106
# Number of pages scraped = 107
# Number of pages scraped = 108
# Number of pages scraped = 109
# Number of pages scraped = 110
# Number of pages scraped = 111
# Number of pages scraped = 112
# Number of pages scraped = 113
# Number of pages scraped = 114
# Number of pages scraped = 115
# Number of pages scraped = 116
# Number of pages scraped = 117
# Number of pages scraped = 118
# Number of pages scraped = 119
# Number of pages scraped = 120
# Number of pages scraped = 121
# Number of pages scraped = 122
# Number of pages scraped = 123
# Number of pages scraped = 124
# Number of pages scraped = 125
# Number of pages scraped = 126
# Number of pages scraped = 127
# Number of pages scraped = 128
# Number of pages scraped = 129
# Number of pages scraped = 130
# Number of pages scraped = 131
# Number of pages scraped = 132
# Number of pages scraped = 133
# Number of pages scraped = 134
# Number of pages scraped = 135
# Number of pages scraped = 136
# Number of pages scraped = 137
# Number of pages scraped = 138
# Number of pages scraped = 139
# Number of pages scraped = 140
# Number of pages scraped = 141
# Number of pages scraped = 142
# Number of pages scraped = 143
# Number of pages scraped = 144
# Number of pages scraped = 145
# Number of pages scraped = 146
# Number of pages scraped = 147
# Number of pages scraped = 148
# Number of pages scraped = 149
# Number of pages scraped = 150
# Number of pages scraped = 151
# Number of pages scraped = 152
# Number of pages scraped = 153
# Number of pages scraped = 154
# Number of pages scraped = 155
# Number of pages scraped = 156
# Number of pages scraped = 157
# Number of pages scraped = 158
# Number of pages scraped = 159
# Number of pages scraped = 160
# Number of pages scraped = 161
# Number of pages scraped = 162
# Number of pages scraped = 163
# Number of pages scraped = 164
# Number of pages scraped = 165
# Number of pages scraped = 166
# Number of pages scraped = 167
# Number of pages scraped = 168
# Number of pages scraped = 169
# Number of pages scraped = 170
# Number of pages scraped = 171
# Number of pages scraped = 172
# Number of pages scraped = 173
# Number of pages scraped = 174
# Number of pages scraped = 175
# Number of pages scraped = 176
# Number of pages scraped = 177
# Number of pages scraped = 178
# Number of pages scraped = 179
# Number of pages scraped = 180
# Number of pages scraped = 181
# Number of pages scraped = 182
# Number of pages scraped = 183
# Number of pages scraped = 184
# Number of pages scraped = 185
# Number of pages scraped = 186
# Number of pages scraped = 187
# Number of pages scraped = 188
# Number of pages scraped = 189
# Number of pages scraped = 190
# Number of pages scraped = 191
# Number of pages scraped = 192
# Number of pages scraped = 193
# Number of pages scraped = 194
# Number of pages scraped = 195
# Number of pages scraped = 196
# Number of pages scraped = 197
# Number of pages scraped = 198
# Number of pages scraped = 199
# Number of pages scraped = 200
# Number of pages scraped = 201
# Number of pages scraped = 202
# Number of pages scraped = 203
# Number of pages scraped = 204
# Number of pages scraped = 205
# Number of pages scraped = 206
# Number of pages scraped = 207
# Number of pages scraped = 208
# Number of pages scraped = 209
# Number of pages scraped = 210
# Number of pages scraped = 211
# Number of pages scraped = 212
# Number of pages scraped = 213
# Number of pages scraped = 214
# Number of pages scraped = 215
# Number of pages scraped = 216
# Number of pages scraped = 217
# Number of pages scraped = 218
# Number of pages scraped = 219
# Number of pages scraped = 220
# Number of pages scraped = 221
# Number of pages scraped = 222
# Number of pages scraped = 223
# Number of pages scraped = 224
# Number of pages scraped = 225
# Number of pages scraped = 226
# Number of pages scraped = 227
# Number of pages scraped = 228
# Number of pages scraped = 229
# Number of pages scraped = 230
# Number of pages scraped = 231
# Number of pages scraped = 232
# Number of pages scraped = 233
# Number of pages scraped = 234
# Number of pages scraped = 235
# Number of pages scraped = 236
# Number of pages scraped = 237
# Number of pages scraped = 238
# Number of pages scraped = 239
# Number of pages scraped = 240
# Number of pages scraped = 241
# Number of pages scraped = 242
# Number of pages scraped = 243
# Number of pages scraped = 244
# Number of pages scraped = 245
# Number of pages scraped = 246
# Number of pages scraped = 247
# Number of pages scraped = 248
# Number of pages scraped = 249
# Number of pages scraped = 250
# Number of pages scraped = 251
# Number of pages scraped = 252
# Number of pages scraped = 253
# Number of pages scraped = 254
# Number of pages scraped = 255
# Number of pages scraped = 256
# Number of pages scraped = 257
# Number of pages scraped = 258
# Number of pages scraped = 259
# Number of pages scraped = 260
# Number of pages scraped = 261
# Number of pages scraped = 262
# Number of pages scraped = 263
# Number of pages scraped = 264
# Number of pages scraped = 265
# Number of pages scraped = 266
# Number of pages scraped = 267
# Number of pages scraped = 268
# Number of pages scraped = 269
# Number of pages scraped = 270
# Number of pages scraped = 271
# Number of pages scraped = 272
# Number of pages scraped = 273
# Number of pages scraped = 274
# Number of pages scraped = 275
# Number of pages scraped = 276
# Number of pages scraped = 277
# Number of pages scraped = 278
# Number of pages scraped = 279
# Number of pages scraped = 280
# Number of pages scraped = 281
# Number of pages scraped = 282
# Number of pages scraped = 283
# Number of pages scraped = 284
# Number of pages scraped = 285
# Number of pages scraped = 286
# Number of pages scraped = 287
# Number of pages scraped = 288
# Number of pages scraped = 289
# Number of pages scraped = 290
# Number of pages scraped = 291
# Number of pages scraped = 292
# Number of pages scraped = 293
# Number of pages scraped = 294
# Number of pages scraped = 295
# Number of pages scraped = 296
# Number of pages scraped = 297
# Number of pages scraped = 298
# Number of pages scraped = 299
# Number of pages scraped = 300
# Number of pages scraped = 301
# Number of pages scraped = 302
# Number of pages scraped = 303
# Number of pages scraped = 304
# Number of pages scraped = 305
# Number of pages scraped = 306
# Number of pages scraped = 307
# Number of pages scraped = 308
# Number of pages scraped = 309
# Number of pages scraped = 310
# Number of pages scraped = 311
# Number of pages scraped = 312
# Number of pages scraped = 313
# Number of pages scraped = 314
# Number of pages scraped = 315
# Number of pages scraped = 316
# Number of pages scraped = 317
# Number of pages scraped = 318
# Number of pages scraped = 319
# Number of pages scraped = 320
# Number of pages scraped = 321
# Number of pages scraped = 322
# Number of pages scraped = 323
# Number of pages scraped = 324
# Number of pages scraped = 325
# Number of pages scraped = 326
# Number of pages scraped = 327
# Number of pages scraped = 328
# Number of pages scraped = 329
# Number of pages scraped = 330
# Number of pages scraped = 331
# Number of pages scraped = 332
# Number of pages scraped = 333
# Number of pages scraped = 334
# Number of pages scraped = 335
# Number of pages scraped = 336
# Number of pages scraped = 337
# Number of pages scraped = 338
# Number of pages scraped = 339
# Number of pages scraped = 340
# Number of pages scraped = 341
# Number of pages scraped = 342
# Number of pages scraped = 343
# Number of pages scraped = 344
# Number of pages scraped = 345
# Number of pages scraped = 346
# Number of pages scraped = 347
# Number of pages scraped = 348
# Number of pages scraped = 349
# Number of pages scraped = 350
# Number of pages scraped = 351
# Number of pages scraped = 352
# Number of pages scraped = 353
# Number of pages scraped = 354
# Number of pages scraped = 355
# Number of pages scraped = 356
# Number of pages scraped = 357
# Number of pages scraped = 358
# Number of pages scraped = 359
# Number of pages scraped = 360
# Number of pages scraped = 361
# Number of pages scraped = 362
# Number of pages scraped = 363
# Number of pages scraped = 364
# Number of pages scraped = 365
# Number of pages scraped = 366
# Number of pages scraped = 367
# Number of pages scraped = 368
# Number of pages scraped = 369
# Number of pages scraped = 370
# Number of pages scraped = 371
# Number of pages scraped = 372
# Number of pages scraped = 373
# Number of pages scraped = 374
# Number of pages scraped = 375
# Number of pages scraped = 376
# Number of pages scraped = 377
# Number of pages scraped = 378
# Number of pages scraped = 379
# Number of pages scraped = 380
# Number of pages scraped = 381
# Number of pages scraped = 382
# Number of pages scraped = 383
# Number of pages scraped = 384
# Number of pages scraped = 385
# Number of pages scraped = 386
# Number of pages scraped = 387
# Number of pages scraped = 388
# Number of pages scraped = 389
# Number of pages scraped = 390
# Number of pages scraped = 391
# Number of pages scraped = 392
# Number of pages scraped = 393
# Number of pages scraped = 394
# Number of pages scraped = 395
# Number of pages scraped = 396
# Number of pages scraped = 397
# Number of pages scraped = 398
# Number of pages scraped = 399
# Number of pages scraped = 400
# Number of pages scraped = 401
# Number of pages scraped = 402
# Number of pages scraped = 403
# Number of pages scraped = 404
# Number of pages scraped = 405
# Number of pages scraped = 406
# Number of pages scraped = 407
# Number of pages scraped = 408
# Number of pages scraped = 409
# Number of pages scraped = 410
# Number of pages scraped = 411
# Number of pages scraped = 412
# Number of pages scraped = 413
# Number of pages scraped = 414
# Number of pages scraped = 415
# Number of pages scraped = 416
# Number of pages scraped = 417
# Number of pages scraped = 418
# Number of pages scraped = 419
# Number of pages scraped = 420
# Number of pages scraped = 421
# Number of pages scraped = 422
# Number of pages scraped = 423
# Number of pages scraped = 424
# Number of pages scraped = 425
# Number of pages scraped = 426
# Number of pages scraped = 427
# Number of pages scraped = 428
# Number of pages scraped = 429
# Number of pages scraped = 430
# Number of pages scraped = 431
# Number of pages scraped = 432
# Number of pages scraped = 433
# Number of pages scraped = 434
# Number of pages scraped = 435
# Number of pages scraped = 436
# Number of pages scraped = 437
# Number of pages scraped = 438
# Number of pages scraped = 439
# Number of pages scraped = 440
# Number of pages scraped = 441
# Number of pages scraped = 442
# Number of pages scraped = 443
# Number of pages scraped = 444
# Number of pages scraped = 445
# Number of pages scraped = 446
# Number of pages scraped = 447
# Number of pages scraped = 448
# Number of pages scraped = 449
# Number of pages scraped = 450
# Number of pages scraped = 451
# Number of pages scraped = 452
# Number of pages scraped = 453
# Number of pages scraped = 454
# Number of pages scraped = 455
# Number of pages scraped = 456
# Number of pages scraped = 457
# Number of pages scraped = 458
# Number of pages scraped = 459
# Number of pages scraped = 460
# Number of pages scraped = 461
# Number of pages scraped = 462
# Number of pages scraped = 463
# Number of pages scraped = 464
# Number of pages scraped = 465
# Number of pages scraped = 466
# Number of pages scraped = 467
# Number of pages scraped = 468
# Number of pages scraped = 469
# Number of pages scraped = 470
# Number of pages scraped = 471
# Number of pages scraped = 472
# Number of pages scraped = 473
# Number of pages scraped = 474
# Number of pages scraped = 475
# Number of pages scraped = 476
# Number of pages scraped = 477
# Number of pages scraped = 478
# Number of pages scraped = 479
# Number of pages scraped = 480
# Number of pages scraped = 481
# Number of pages scraped = 482
# Number of pages scraped = 483
# Number of pages scraped = 484
# Number of pages scraped = 485
# Number of pages scraped = 486
# Number of pages scraped = 487
# Number of pages scraped = 488
# Number of pages scraped = 489
# Number of pages scraped = 490
# Number of pages scraped = 491
# Number of pages scraped = 492
# Number of pages scraped = 493
# Number of pages scraped = 494
# Number of pages scraped = 495
# Number of pages scraped = 496
# Number of pages scraped = 497
# Number of pages scraped = 498
# Number of pages scraped = 499
# Number of pages scraped = 500
# Number of pages scraped = 501
# Number of pages scraped = 502
# Number of pages scraped = 503
# Number of pages scraped = 504
# Number of pages scraped = 505
# Number of pages scraped = 506
# Number of pages scraped = 507
# Number of pages scraped = 508
# Number of pages scraped = 509
# Number of pages scraped = 510
# Number of pages scraped = 511
# Number of pages scraped = 512
# Number of pages scraped = 513
# Number of pages scraped = 514
# Number of pages scraped = 515
# Number of pages scraped = 516
# Number of pages scraped = 517
# Number of pages scraped = 518
# Number of pages scraped = 519
# Number of pages scraped = 520
# Number of pages scraped = 521
# Number of pages scraped = 522
# Number of pages scraped = 523
# Number of pages scraped = 524
# Number of pages scraped = 525
# Number of pages scraped = 526
# Number of pages scraped = 527
# Number of pages scraped = 528
# Number of pages scraped = 529
# Number of pages scraped = 530
# Number of pages scraped = 531
# Number of pages scraped = 532
# Number of pages scraped = 533
# Number of pages scraped = 534
# Number of pages scraped = 535
# Number of pages scraped = 536
# Number of pages scraped = 537
# Number of pages scraped = 538
# Number of pages scraped = 539
# Number of pages scraped = 540
# Number of pages scraped = 541
# Number of pages scraped = 542
# Number of pages scraped = 543
# Number of pages scraped = 544
# Number of pages scraped = 545
# Number of pages scraped = 546
# Number of pages scraped = 547
# Number of pages scraped = 548
# Number of pages scraped = 549
# Number of pages scraped = 550
# Number of pages scraped = 551
# Number of pages scraped = 552
# Number of pages scraped = 553
# Number of pages scraped = 554
# Number of pages scraped = 555
# Number of pages scraped = 556
# Number of pages scraped = 557
# Number of pages scraped = 558
# Number of pages scraped = 559
# Number of pages scraped = 560
# Number of pages scraped = 561
# Number of pages scraped = 562
# Number of pages scraped = 563
# Number of pages scraped = 564
# Number of pages scraped = 565
# Number of pages scraped = 566
# Number of pages scraped = 567
# Number of pages scraped = 568
# Number of pages scraped = 569
# Number of pages scraped = 570
# Number of pages scraped = 571
# Number of pages scraped = 572
# Number of pages scraped = 573
# Number of pages scraped = 574
# Number of pages scraped = 575
# Number of pages scraped = 576
# Number of pages scraped = 577
# Number of pages scraped = 578
# Number of pages scraped = 579
# Number of pages scraped = 580
# Number of pages scraped = 581
# Number of pages scraped = 582
# Number of pages scraped = 583
# Number of pages scraped = 584
# Number of pages scraped = 585
# Number of pages scraped = 586
# Number of pages scraped = 587
# Number of pages scraped = 588
# Number of pages scraped = 589
# Number of pages scraped = 590
# Number of pages scraped = 591
# Number of pages scraped = 592
# Number of pages scraped = 593
# Number of pages scraped = 594
# Number of pages scraped = 595
# Number of pages scraped = 596
# Number of pages scraped = 597
# Number of pages scraped = 598
# Number of pages scraped = 599
# Number of pages scraped = 600
# Number of pages scraped = 601
# Number of pages scraped = 602
# Number of pages scraped = 603
# Number of pages scraped = 604
# Number of pages scraped = 605
# Number of pages scraped = 606
# Number of pages scraped = 607
# Number of pages scraped = 608
# Number of pages scraped = 609
# Number of pages scraped = 610
# Number of pages scraped = 611
# Number of pages scraped = 612
# Number of pages scraped = 613
# Number of pages scraped = 614
# Number of pages scraped = 615
# Number of pages scraped = 616
# Number of pages scraped = 617
# Number of pages scraped = 618
# Number of pages scraped = 619
# Number of pages scraped = 620
# Number of pages scraped = 621
# Number of pages scraped = 622
# Number of pages scraped = 623
# Number of pages scraped = 624
# Number of pages scraped = 625
# Number of pages scraped = 626
# Number of pages scraped = 627
# Number of pages scraped = 628
# Number of pages scraped = 629
# Number of pages scraped = 630
# Number of pages scraped = 631
# Number of pages scraped = 632
# Number of pages scraped = 633
# Number of pages scraped = 634
# Number of pages scraped = 635
# Number of pages scraped = 636
# Number of pages scraped = 637
# Number of pages scraped = 638
# Number of pages scraped = 639
# Number of pages scraped = 640
# Number of pages scraped = 641
# Number of pages scraped = 642
# Number of pages scraped = 643
# Number of pages scraped = 644
# Number of pages scraped = 645
# Number of pages scraped = 646
# Number of pages scraped = 647
# Number of pages scraped = 648
# Number of pages scraped = 649
# Number of pages scraped = 650
# Number of pages scraped = 651
# Number of pages scraped = 652
# Number of pages scraped = 653
# Number of pages scraped = 654
# Number of pages scraped = 655
# Number of pages scraped = 656
# Number of pages scraped = 657
# Number of pages scraped = 658
# Number of pages scraped = 659
# Number of pages scraped = 660
# Number of pages scraped = 661
# Number of pages scraped = 662
# Number of pages scraped = 663
# Number of pages scraped = 664
# Number of pages scraped = 665
# Number of pages scraped = 666
# Number of pages scraped = 667
# Number of pages scraped = 668
# Number of pages scraped = 669
# Number of pages scraped = 670
# Number of pages scraped = 671
# Number of pages scraped = 672
# Number of pages scraped = 673
# Number of pages scraped = 674
# Number of pages scraped = 675
# Number of pages scraped = 676
# Number of pages scraped = 677
# Number of pages scraped = 678
# Number of pages scraped = 679
# Number of pages scraped = 680
# Number of pages scraped = 681
# Number of pages scraped = 682
# Number of pages scraped = 683
# Number of pages scraped = 684
# Number of pages scraped = 685
# Number of pages scraped = 686
# Number of pages scraped = 687
# Number of pages scraped = 688
# Number of pages scraped = 689
# Number of pages scraped = 690
# Number of pages scraped = 691
# Number of pages scraped = 692
# Number of pages scraped = 693
# Number of pages scraped = 694
# Number of pages scraped = 695
# Number of pages scraped = 696
# Number of pages scraped = 697
# Number of pages scraped = 698
# Number of pages scraped = 699
# Number of pages scraped = 700
# Number of pages scraped = 701
# Number of pages scraped = 702
# Number of pages scraped = 703
# Number of pages scraped = 704
# Number of pages scraped = 705
# Number of pages scraped = 706
# Number of pages scraped = 707
# Number of pages scraped = 708
# Number of pages scraped = 709
# Number of pages scraped = 710
# Number of pages scraped = 711
# Number of pages scraped = 712
# Number of pages scraped = 713
# Number of pages scraped = 714
# Number of pages scraped = 715
# Number of pages scraped = 716
# Number of pages scraped = 717
# Number of pages scraped = 718
# Number of pages scraped = 719
# Number of pages scraped = 720
# Number of pages scraped = 721
# Number of pages scraped = 722
# Number of pages scraped = 723
# Number of pages scraped = 724
# Number of pages scraped = 725
# Number of pages scraped = 726
# Number of pages scraped = 727
# Number of pages scraped = 728
# Number of pages scraped = 729
# Number of pages scraped = 730
# Number of pages scraped = 731
# Number of pages scraped = 732
# Number of pages scraped = 733
# Number of pages scraped = 734
# Number of pages scraped = 735
# Number of pages scraped = 736
# Number of pages scraped = 737
# Number of pages scraped = 738
# Number of pages scraped = 739
# Number of pages scraped = 740
# Number of pages scraped = 741
# Number of pages scraped = 742
# Number of pages scraped = 743
# Number of pages scraped = 744
# Number of pages scraped = 745
# Number of pages scraped = 746
# Number of pages scraped = 747
# Number of pages scraped = 748
# Number of pages scraped = 749
# Number of pages scraped = 750
# Number of pages scraped = 751
# Number of pages scraped = 752
# Number of pages scraped = 753
# Number of pages scraped = 754
# Number of pages scraped = 755
# Number of pages scraped = 756
# Number of pages scraped = 757
# Number of pages scraped = 758
# Number of pages scraped = 759
# Number of pages scraped = 760
# Number of pages scraped = 761
# Number of pages scraped = 762
# Number of pages scraped = 763
# Number of pages scraped = 764
# Number of pages scraped = 765
# Number of pages scraped = 766
# Number of pages scraped = 767
# Number of pages scraped = 768
# Number of pages scraped = 769
# Number of pages scraped = 770
# Number of pages scraped = 771
# Number of pages scraped = 772
# Number of pages scraped = 773
# Number of pages scraped = 774
# Number of pages scraped = 775
# Number of pages scraped = 776
# Number of pages scraped = 777
# Number of pages scraped = 778
# Number of pages scraped = 779
# Number of pages scraped = 780
# Number of pages scraped = 781
# Number of pages scraped = 782
# Number of pages scraped = 783
# Number of pages scraped = 784
# Number of pages scraped = 785
# Number of pages scraped = 786
# Number of pages scraped = 787
# Number of pages scraped = 788
# Number of pages scraped = 789
# Number of pages scraped = 790
# Number of pages scraped = 791
# Number of pages scraped = 792
# Number of pages scraped = 793
# Number of pages scraped = 794
# Number of pages scraped = 795
# Number of pages scraped = 796
# Number of pages scraped = 797
# Number of pages scraped = 798
# Number of pages scraped = 799
# Number of pages scraped = 800
# Number of pages scraped = 801
# Number of pages scraped = 802
# Number of pages scraped = 803
# Number of pages scraped = 804
# Number of pages scraped = 805
# Number of pages scraped = 806
# Number of pages scraped = 807
# Number of pages scraped = 808
# Number of pages scraped = 809
# Number of pages scraped = 810
# Number of pages scraped = 811
# Number of pages scraped = 812
# Number of pages scraped = 813
# Number of pages scraped = 814
# Number of pages scraped = 815
# Number of pages scraped = 816
# Number of pages scraped = 817
# Number of pages scraped = 818
# Number of pages scraped = 819
# Number of pages scraped = 820
# Number of pages scraped = 821
# Number of pages scraped = 822
# Number of pages scraped = 823
# Number of pages scraped = 824
# Number of pages scraped = 825
# Number of pages scraped = 826
# Number of pages scraped = 827
# Number of pages scraped = 828
# Number of pages scraped = 829
# Number of pages scraped = 830
# Number of pages scraped = 831
# Number of pages scraped = 832
# Number of pages scraped = 833
# Number of pages scraped = 834
# Number of pages scraped = 835
# Number of pages scraped = 836
# Number of pages scraped = 837
# Number of pages scraped = 838
# Number of pages scraped = 839
# Number of pages scraped = 840
# Number of pages scraped = 841
# Number of pages scraped = 842
# Number of pages scraped = 843
# Number of pages scraped = 844
# Number of pages scraped = 845
# Number of pages scraped = 846
# Number of pages scraped = 847
# Number of pages scraped = 848
# Number of pages scraped = 849
# Number of pages scraped = 850
# Number of pages scraped = 851
# Number of pages scraped = 852
# Number of pages scraped = 853
# Number of pages scraped = 854
# Number of pages scraped = 855
# Number of pages scraped = 856
# Number of pages scraped = 857
# Number of pages scraped = 858
# Number of pages scraped = 859
# Number of pages scraped = 860
# Number of pages scraped = 861
# Number of pages scraped = 862
# Number of pages scraped = 863
# Number of pages scraped = 864
# Number of pages scraped = 865
# Number of pages scraped = 866
# Number of pages scraped = 867
# Number of pages scraped = 868
# Number of pages scraped = 869
# Number of pages scraped = 870
# Number of pages scraped = 871
# Number of pages scraped = 872
# Number of pages scraped = 873
# Number of pages scraped = 874
# Number of pages scraped = 875
# Number of pages scraped = 876
# Number of pages scraped = 877
# Number of pages scraped = 878
# Number of pages scraped = 879
# Number of pages scraped = 880
# Number of pages scraped = 881
# Number of pages scraped = 882
# Number of pages scraped = 883
# Number of pages scraped = 884
# Number of pages scraped = 885
# Number of pages scraped = 886
# Number of pages scraped = 887
# Number of pages scraped = 888
# Number of pages scraped = 889
# Number of pages scraped = 890
# Number of pages scraped = 891
# Number of pages scraped = 892
# Number of pages scraped = 893
# Number of pages scraped = 894
# Number of pages scraped = 895
# Number of pages scraped = 896
# Number of pages scraped = 897
# Number of pages scraped = 898
# Number of pages scraped = 899
# Number of pages scraped = 900

# %% [markdown]
# Storage
# -------
#
# The dataset contains 900 entries and isn't very big. For our purposes, we can simply leave it as a list of dictionaries and serialize it as a pickle.

# %%
import pickle

f = open('airbnb_data.pkl','w')
pickle.dump(items,f)
f.close()
